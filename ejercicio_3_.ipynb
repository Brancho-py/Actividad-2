# %% [markdown]
# <a href="https://colab.research.google.com/github/Brancho-py/Actividad-2/blob/main/ejercicio_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Automovil:
    def __init__(self, marca, modelo, motor, tipo_combustible,
                 tipo_automovil, numero_puertas, cantidad_asientos,
                 velocidad_maxima, color):

        self.marca = marca
        self.modelo = modelo
        self.motor = motor
        self.tipo_combustible = tipo_combustible.upper()
        self.tipo_automovil = tipo_automovil.upper()
        self.numero_puertas = numero_puertas
        self.cantidad_asientos = cantidad_asientos
        self.velocidad_maxima = velocidad_maxima
        self.color = color.upper()
        self.velocidad_actual = 0


    def get_velocidad_actual(self):
        return self.velocidad_actual

    def set_velocidad_actual(self, velocidad):
        self.velocidad_actual = velocidad


    def acelerar(self, incremento):
        if self.velocidad_actual + incremento <= self.velocidad_maxima:
            self.velocidad_actual += incremento
        else:
            print("No se puede incrementar a una velocidad superior a la máxima del automóvil.")

    def desacelerar(self, decremento):
        if self.velocidad_actual - decremento >= 0:
            self.velocidad_actual -= decremento
        else:
            print("No se puede decrementar a una velocidad negativa.")

    def frenar(self):
        self.velocidad_actual = 0

    def mostrar(self):
        print("\n--- AUTOMÓVIL ---")
        print("Marca =", self.marca)
        print("Modelo =", self.modelo)
        print("Motor =", self.motor)
        print("Tipo de combustible =", self.tipo_combustible)
        print("Tipo de automóvil =", self.tipo_automovil)
        print("Número de puertas =", self.numero_puertas)
        print("Cantidad de asientos =", self.cantidad_asientos)
        print("Velocidad máxima =", self.velocidad_maxima)
        print("Color =", self.color)




autos = []

n = int(input("¿Cuántos autos?: "))

for i in range(n):
    print(f"\nAuto {i+1}")
    marca = input("Marca: ")
    modelo = int(input("Modelo: "))
    motor = int(input("Motor: "))
    combustible = input("Tipo de combustible: ")
    tipo = input("Tipo de automóvil: ")
    puertas = int(input("Número de puertas: "))
    asientos = int(input("Cantidad de asientos: "))
    vmax = int(input("Velocidad máxima: "))
    color = input("Color: ")

    auto = Automovil(marca, modelo, motor, combustible, tipo,
                     puertas, asientos, vmax, color)

    autos.append(auto)




for a in autos:
    a.mostrar()

    a.set_velocidad_actual(100)
    print("Velocidad actual =", a.get_velocidad_actual())

    a.acelerar(20)
    print("Velocidad actual =", a.get_velocidad_actual())

    a.desacelerar(50)
    print("Velocidad actual =", a.get_velocidad_actual())

    a.frenar()
    print("Velocidad actual =", a.get_velocidad_actual())


    a.desacelerar(20)
# Out:
# ¿Cuántos autos?: 1
#
# Auto 1
# Marca: ttoyota
# Modelo: 2011
# Motor: 2
# Tipo de combustible: gasolina
# Tipo de automóvil: bus
# Número de puertas: 4
# Cantidad de asientos: 20
# Velocidad máxima: 80
# Color: negro
#
# --- AUTOMÓVIL ---
# Marca = ttoyota
# Modelo = 2011
# Motor = 2
# Tipo de combustible = GASOLINA
# Tipo de automóvil = BUS
# Número de puertas = 4
# Cantidad de asientos = 20
# Velocidad máxima = 80
# Color = NEGRO
# Velocidad actual = 100
# No se puede incrementar a una velocidad superior a la máxima del automóvil.
# Velocidad actual = 100
# Velocidad actual = 50
# Velocidad actual = 0
# No se puede decrementar a una velocidad negativa.
